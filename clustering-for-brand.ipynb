# %%
import pandas as pd
import os
import openai

# %%
# Load your API key from an environment variable or secret management service
openai.api_key = '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'

# %%
response = openai.Completion.create(model="text-davinci-003", prompt="Say this is a test", temperature=0, max_tokens=7)
response

# %%
sentences = pd.read_csv("/Users/jackzellweger/Desktop/SentencesExport.csv")

# %%
def get_embedding(text, model="text-embedding-ada-002"):
   text = text.replace("\n", " ")
   return openai.Embedding.create(input = [text], model=model)['data'][0]['embedding']

# %%
response = openai.Embedding.create(
    input="Hi, I'm Jack",
    model="text-embedding-ada-002"
)
embeddings = response['data'][0]['embedding']

# %%
len(embeddings)
# Out:
# 1536

# %%
for x, y in sentences:
    print(x)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [31], in <cell line: 1>()
# ----> 1 for x, y in sentences:
#       2     print(x)
#
# ValueError: too many values to unpack (expected 2)

# %%
sent1= ["High Performance Computing", "Taking Us to the Far Reaches of Space", 
  "Learn More", 
  "Defining Possible through your Career in Science Technology and Engineering", 
  "It's only impossible \[Dash] until you do it at Northrop Grumman", "Learn More", 
  "For some the word 'impossible' ends discussions", 
  " For us it's a starting point", "Technology and Innovation", "Learn More", 
  "Neuromorphic Cameras", "Providing a Vision of the Future", "Learn More", 
  "Modernizing the B52", "How Raytheon Technologies can help keep the legendary aircraft flying through 2050", "Connecting the aviation ecosystem", 
  "Meet the scholars redefining the future of STEM", 
  "The future of aerospace and defense tech in Canada", 
  "Made for the moments that matter", "Safer more connected flight", 
  "Safer more connected flight", "Smarter defense systems", 
  "Smarter defense systems", "Intelligent space technologies", 
  "Intelligent space technologies", "We are advancing aviation building smarter defense systems and creating innovations to take us deeper into space", 
  "Who we are", "Learn more", "Tech and talent to transform the world", 
  "Our people and capabilities form an innovation powerhouse", "Collins Aerospace", 
  "Pratt & Whitney", "Raytheon Intelligence & Space", 
  "Raytheon Missiles & Defense", "COVID19 information and resources", "Learn more"]

# %%
print (sent1[:3])
# Out:
# ['High Performance Computing', 'Taking Us to the Far Reaches of Space', 'Learn More']

# %%
embeddingsArr = []

for x in sent1[:3]:
    response = openai.Embedding.create(
    input=x,
    model="text-embedding-ada-002")
    embeddings = response['data'][0]['embedding']
    embeddingsArr.append(embeddings)

embeddingsArr
# Out:
# [[-0.023454733192920685,
#   -0.002238738816231489,
#   0.012338236905634403,
#   -0.03286616504192352,
#   -0.00025928422110155225,
#   0.01915850304067135,
#   -0.00925703439861536,
#   0.011868337169289589,
#   0.008659590035676956,
#   -0.044465985149145126,
#   0.02703940123319626,
#   0.022058458998799324,
#   0.018634900450706482,
#   -0.01804416812956333,
#   -0.0032322423066943884,
#   0.00747812632471323,
#   0.0172923281788826,
#   -0.017346030101180077,
#   -0.0013895620359107852,
#   0.00032158795511350036,
#   -0.030583791434764862,
#   0.009686657227575779,
#   0.005084991455078125,
#   -0.002812688471749425,
#   -0.01839323714375496,
#   -0.0004145191051065922,
#   0.02859678491950035,
#   -0.03101341426372528,
#   0.002500540344044566,
#   -0.015426152385771275,
#   0.0072163245640695095,
#   -0.017507139593362808,
#   -0.010190121829509735,
#   -0.014969678595662117,
#   -0.03278560936450958,
#   0.004581527318805456,
#   0.001686606090515852,
# ...

# %%
# Out:
# 3
